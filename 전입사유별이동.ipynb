# %% [markdown]
# <a href="https://colab.research.google.com/github/audwls4545/metaverse/blob/main/%EC%A0%84%EC%9E%85%EC%82%AC%EC%9C%A0%EB%B3%84%EC%9D%B4%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
# !pip install pyreadstat

import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import koreanize_matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('/content/drive/MyDrive/colab_data_file/전출지_전입지_시도__전입사유별_이동자수_20230607091340.csv',encoding='euc-kr')
data.head()
# Out:
#   전출지별 전입지별 전입사유별     2020     2021     2022
# 0   전국   전국     계  7735491  7213422  6152155
# 1   전국   전국    직업  1636565  1588848  1439717
# 2   전국   전국    가족  1795307  1657034  1459371
# 3   전국   전국    주택  3004510  2714294  2116410
# 4   전국   전국    교육   346112   320002   329034

# %%
data = data.loc[:,['전입사유별','2020','2021','2022']]
data = data.drop(data.index[0])
data.head()
# Out:
#   전입사유별     2020     2021     2022
# 1    직업  1636565  1588848  1439717
# 2    가족  1795307  1657034  1459371
# 3    주택  3004510  2714294  2116410
# 4    교육   346112   320002   329034
# 5  주거환경   341937   312481   277194

# %%
data = data.iloc[0:6]
data
# Out:
#   전입사유별     2020     2021     2022
# 1    직업  1636565  1588848  1439717
# 2    가족  1795307  1657034  1459371
# 3    주택  3004510  2714294  2116410
# 4    교육   346112   320002   329034
# 5  주거환경   341937   312481   277194
# 6  자연환경    89274    86651    74564

# %%
data.plot.barh(x='전입사유별', alpha=0.5, stacked=True, figsize=(20,5))
plt.title('전입사유별이동')
plt.xlabel('수')
plt.ylabel('전입사유')
plt.xticks(rotation=0)
plt.show()
