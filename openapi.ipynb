# %% [markdown]
# <a href="https://colab.research.google.com/github/audwls4545/metaverse/blob/main/openapi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#naverid : 2DMMm2FaJ2AwC3o2sbvS
#pw : 1O05ffjh8O

# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json
import pandas as pd

client_id = "2DMMm2FaJ2AwC3o2sbvS"
client_secret = "1O05ffjh8O"

def naver_blog(keyword):

    encText = urllib.parse.quote(keyword)

    result_list = []

    for i in range(1,1000,100):
        url = "https://openapi.naver.com/v1/search/blog?query=" + encText +'&display=100&sort=sim&start='+str(i) # JSON 결과
        # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()
            response_json = json.loads(response_body)

            result_data = response_json['items']
            
            for temp in result_data:
                blog_data = {}

                blog_title = temp['title']
                blog_link = temp['link']
                blog_description = temp['description']

                blog_data['title'] = blog_title
                blog_data['link'] = blog_link
                blog_data['description'] = blog_description

                result_list.append(blog_data)
    
            #print(response_body.decode('utf-8'))
        else:
            print("Error Code:" + rescode)

    print('블로그 개수:', len(result_data)) 
    blog = pd.DataFrame.from_dict(result_list)
    return blog

naver_blog('메타버스')
# Out:
# 블로그 개수: 100
#                                                title  \
# 0                           <b>메타버스</b>교육 수업 커리큘럼 확인
# 1       3차원 <b>메타버스</b> &apos;통일 한반도, 또 하나의 세계&apos;
# 2                    샌드박스 코인 전망 시세 <b>메타버스</b>의 미래는?
# 3                      여하튼 <b>메타버스</b> 온라인 상담 받은 신입생
# 4       언리얼엔진 <b>메타버스</b> 교육 및 실감 콘텐츠 개발자를 위한 뉴딜...
# ..                                               ...
# 995            <b>메타버스</b> 초보자가 가장 알고 싶은 최다질문 TOP 45
# 996                   가상학습, <b>메타버스</b> 교육 시작하고 싶다면?
# 997                   <b>메타버스</b> ZEP활용법 온라인클레스 무료특강
# 998       프롭테크 유니콘 기업 직방의 <b>메타버스</b> 오피스 soma 체험 후기
# 999  <b>메타버스</b> 이상한도서관 <b>메타버스</b>제작 <b>메타버스</b>콘텐츠
#
#                                                   link  \
# 0         https://blog.naver.com/notgloom/223050910175
# 1         https://blog.naver.com/nuacmail/223066427291
# 2          https://blog.naver.com/howgkdn/223093641010
# 3            https://blog.naver.com/dromg/223063767512
# ...

# %%
#naverid : 2DMMm2FaJ2AwC3o2sbvS
#pw : 1O05ffjh8O

# 네이버 검색 API 예제 - 카페 검색
import os
import sys
import urllib.request
import json
import pandas as pd

client_id = "2DMMm2FaJ2AwC3o2sbvS"
client_secret = "1O05ffjh8O"

def naver_cafe(keyword):

    encText = urllib.parse.quote(keyword)

    result_list = []

    for i in range(1,1000,100):
        url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText +'&display=100&sort=sim&start='+str(i) # JSON 결과
        # url = "https://openapi.naver.com/v1/search/cafearticle.xml?query=" + encText # XML 결과
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()
            response_json = json.loads(response_body)

            result_data = response_json['items']
            
            for temp in result_data:
                cafe_data = {}

                cafe_title = temp['title']
                cafe_link = temp['link']
                cafe_description = temp['description']

                cafe_data['title'] = cafe_title
                cafe_data['link'] = cafe_link
                cafe_data['description'] = cafe_description

                result_list.append(cafe_data)
    
            #print(response_body.decode('utf-8'))
        else:
            print("Error Code:" + rescode)

    cafe = pd.DataFrame.from_dict(result_list)
    return cafe

naver_cafe('메타버스')
# Out:
# 카페 개수: 100
#                                                  title  \
# 0           [반크X외교부] 디지털 <b>메타버스</b> 외교관 2기 모집 (~5/14)
# 1                                 한양대입학설명회:<b>메타버스</b>
# 2                     <b>메타버스</b> ETF는 관심있는분은 1개 장만하세요
# 3          [IT조선] '<b>메타버스</b>ESG 콘퍼런스' 서포터즈 모집(~4/17)
# 4                 [이벤트] <b>메타버스</b> 초등 영어앱 알아보고 스벅 가자!
# ..                                                 ...
# 995                               <b>메타버스</b>ETF 상장 관련
# 996                                 <b>메타버스</b>와 돈의 미래
# 997                     [슬로래빗] 난데없이 <b>메타버스</b> 서평단 모집
# 998                                <b>메타버스</b> 뜻과 관련회사
# 999  장중 특징테마,시황체크(2/24) (AI,AI반도체,엔비디아,의료AI,<b>메타버스...
#
#                                             link  \
# 0           http://cafe.naver.com/specup/7265435
# 1         http://cafe.naver.com/hinongusul/13958
# 2          http://cafe.naver.com/geobuk2/1716926
# 3           http://cafe.naver.com/specup/7251996
# ...

# %%
#naverid : 2DMMm2FaJ2AwC3o2sbvS
#pw : 1O05ffjh8O

# 네이버 검색 API 예제 - 카페 검색
import os
import sys
import urllib.request
import json
import pandas as pd

client_id = "2DMMm2FaJ2AwC3o2sbvS"
client_secret = "1O05ffjh8O"

def naver_news(keyword):

    encText = urllib.parse.quote(keyword)

    result_list = []

    for i in range(1,1000,100):
        url = "https://openapi.naver.com/v1/search/news?query=" + encText +'&display=100&sort=sim&start='+str(i) # JSON 결과
        # url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # XML 결과
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()
            response_json = json.loads(response_body)

            result_data = response_json['items']
            
            for temp in result_data:
                news_data = {}

                news_title = temp['title']
                news_link = temp['link']
                news_description = temp['description']

                news_data['title'] = news_title
                news_data['link'] = news_link
                news_data['description'] = news_description

                result_list.append(news_data)
    
            #print(response_body.decode('utf-8'))
        else:
            print("Error Code:" + rescode)

    news = pd.DataFrame.from_dict(result_list)
    return news

naver_news('메타버스')
# Out:
#                                                  title  \
# 0                 광주 남부경찰, 청소년 마약 범죄 예방 <b>메타버스</b> 제작
# 1    SKT, 3D로 꾸미는 나만의 <b>메타버스</b> 공간 &apos;이프홈&apos...
# 2                SKT, <b>메타버스</b> 세상 속 나만의 공간 ‘이프홈’ 오픈
# 3                갤럭시아<b>메타버스</b>, RWA 기반 렌딩 프로토콜 개발 참여
# 4                    SKT, 나만의 <b>메타버스</b> 공간 ‘이프홈’ 열었다
# ..                                                 ...
# 995          넷마블에프앤씨-대한항공, <b>메타버스</b>·디지털휴먼 협업 MOU 체결
# 996  대전학생교육문화원, 학교로 찾아가는 &apos;무한상상, <b>메타버스</b>&ap...
# 997          패스커, 2030 MZ세대 패션 <b>메타버스</b>몰 서비스 글로벌 론칭
# 998       [경북도정] 국민참여형 &apos;기부자의 숲&apos; 나무심기 행사 동참 外
# 999              이달희 경북도 경제부지사, 미래 전략산업 현안해결 위해 과기부 방문
#
#                                                   link  \
# 0    https://n.news.naver.com/mnews/article/421/000...
# 1    https://n.news.naver.com/mnews/article/001/001...
# 2    https://n.news.naver.com/mnews/article/243/000...
# 3    https://n.news.naver.com/mnews/article/018/000...
# ...

# %%
#naverid : 2DMMm2FaJ2AwC3o2sbvS
#pw : 1O05ffjh8O

# 네이버 검색 API 예제 - 파파고 검색
import os
import sys
import urllib.request
import json
import pandas as pd

client_id = "2DMMm2FaJ2AwC3o2sbvS"
client_secret = "1O05ffjh8O"

def naver_papago(text, target='en'):
    encText = urllib.parse.quote(text)
    #data = "source=ko&target=en&text=" + encText#영어
    #data = "source=ko&target=ja&text=" + encText#일본어
    data = "source=ko&target=" + target + "&text=" + encText
    url = "https://openapi.naver.com/v1/papago/n2mt"
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()

        json_data = json.loads(response_body)
        result_data = json_data['message']['result']['translatedText']
        print(result_data)
        #print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)

    return result_data

naver_papago('메타버스는 앞으로 새로운 시대를 열어줄거에요.')
# Out:
# Metaverse will usher in a new era.
# 'Metaverse will usher in a new era.'
