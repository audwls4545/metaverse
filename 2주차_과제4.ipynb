# %% [markdown]
# <a href="https://colab.research.google.com/github/audwls4545/metaverse/blob/main/2%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 2s (4,457 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='NanumBarunGothic')

# %%
import pandas as pd
df = pd.read_csv('서울특별시+공공자전거+이용정보(월별)_22.06.csv', encoding='cp949')
df
# Out:
#            대여일자  대여소번호            대여소명   대여구분코드  성별 연령대코드  이용건수     운동량   탄소량  \
# 0       2022-06      3            중랑센터  일일(비회원)  \N    기타     1   29.34  0.26
# 1       2022-06      3            중랑센터   일일(회원)   M   50대    19  458.11  4.44
# 2       2022-06      3            중랑센터       정기  \N   20대    12  330.13  3.39
# 3       2022-06      3            중랑센터       정기  \N   60대     4  113.53  1.02
# 4       2022-06      3            중랑센터       정기   M   20대     2   13.69  0.07
# ...         ...    ...             ...      ...  ..   ...   ...     ...   ...
# 133096  2022-06   9999            상담센터       정기   M    기타     4  525.03  3.84
# 133097  2022-06  88888      88888.영남배송       정기   M   60대     7  831.71  7.62
# 133098  2022-06  99998   99998. 상암단말정비       정기  \N   20대     1   20.85  0.26
# 133099  2022-06  99999  99999. 영남단말기정비       정기  \N    기타    15    0.00  0.00
# 133100  2022-06  99999  99999. 영남단말기정비       정기   M   30대     1   14.71  0.11
#
#          이동거리(M)  이용시간(분)
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            대여일자  대여소번호            대여소명   대여구분코드  성별 연령대코드  이용건수     운동량   탄소량  \
# 0       2022-06      3            중랑센터  일일(비회원)  \N    기타     1   29.34  0.26
# 1       2022-06      3            중랑센터   일일(회원)   M   50대    19  458.11  4.44
# 2       2022-06      3            중랑센터       정기  \N   20대    12  330.13  3.39
# 3       2022-06      3            중랑센터       정기  \N   60대     4  113.53  1.02
# 4       2022-06      3            중랑센터       정기   M   20대     2   13.69  0.07
# ...         ...    ...             ...      ...  ..   ...   ...     ...   ...
# 133096  2022-06   9999            상담센터       정기   M    기타     4  525.03  3.84
# 133097  2022-06  88888      88888.영남배송       정기   M   60대     7  831.71  7.62
# 133098  2022-06  99998   99998. 상암단말정비       정기  \N   20대     1   20.85  0.26
# 133099  2022-06  99999  99999. 영남단말기정비       정기  \N    기타    15    0.00  0.00
# 133100  2022-06  99999  99999. 영남단말기정비       정기   M   30대     1   14.71  0.11
#
# ...

# %%
df
# Out:
#            대여일자  대여소번호            대여소명   대여구분코드  성별 연령대코드  이용건수     운동량   탄소량  \
# 0       2022-06      3            중랑센터  일일(비회원)  \N    기타     1   29.34  0.26
# 1       2022-06      3            중랑센터   일일(회원)   M   50대    19  458.11  4.44
# 2       2022-06      3            중랑센터       정기  \N   20대    12  330.13  3.39
# 3       2022-06      3            중랑센터       정기  \N   60대     4  113.53  1.02
# 4       2022-06      3            중랑센터       정기   M   20대     2   13.69  0.07
# ...         ...    ...             ...      ...  ..   ...   ...     ...   ...
# 133096  2022-06   9999            상담센터       정기   M    기타     4  525.03  3.84
# 133097  2022-06  88888      88888.영남배송       정기   M   60대     7  831.71  7.62
# 133098  2022-06  99998   99998. 상암단말정비       정기  \N   20대     1   20.85  0.26
# 133099  2022-06  99999  99999. 영남단말기정비       정기  \N    기타    15    0.00  0.00
# 133100  2022-06  99999  99999. 영남단말기정비       정기   M   30대     1   14.71  0.11
#
#          이동거리(M)  이용시간(분)
# ...

# %%
# 가장 많은 대여를 한 대여소와 횟수 확인
rental_dict = {}
count_dict = {}
#print(df[['대여소명','이용건수']])
count = 0
for temp in df['대여소명']:
    rental = temp

    if rental in rental_dict.keys():
        rental_dict[rental] += 1
    else:
        rental_dict[rental] = 1

rental_dict_sort = sorted(rental_dict.items(), key=lambda x: x[1], reverse=True)
rental_dict_sort
# Out:
# [('4217. 한강공원 망원나들목', 88),
#  ('207. 여의나루역 1번출구 앞', 82),
#  ('502. 뚝섬유원지역 1번출구 앞', 82),
#  ('186. 월드컵공원', 79),
#  ('418. 월드컵경기장역 3번출구 옆', 79),
#  ('1210. 롯데월드타워(잠실역2번출구 쪽)', 79),
#  ('2622. 올림픽공원역 3번출구', 79),
#  ('272. 당산육갑문', 78),
#  ('2102. 봉림교 교통섬', 78),
#  ('2262. 한신16차아파트 119동 앞', 78),
#  ('3511. 응봉역 1번출구', 78),
#  ('1153. 발산역 1번, 9번 인근 대여소', 76),
#  ('2613. 잠실나들목', 76),
#  ('2621. 한성백제역 2번 출구', 76),
#  ('2715.마곡나루역 2번 출구 ', 76),
#  ('210. IFC몰', 75),
#  ('853.용산역 맞은편', 75),
#  ('1268. 몽촌토성역 1번출구 옆', 75),
#  ('2002. 노들역 1번출구', 75),
#  ('2177. 신대방역 2번 출구', 75),
#  ('2608. 송파구청', 75),
#  ('3515. 서울숲 관리사무소', 75),
#  ('117. 홍은사거리', 74),
#  ('583. 청계천 생태교실 앞', 74),
#  ('770.목동역5번출구 교통정보센터 앞', 74),
#  ('907. CJ 드림시티', 74),
#  ('1222. 잠실새내역 5번 출구 뒤', 74),
#  ('1295. 잠실역 8번출구', 74),
#  ('2525.반포쇼핑타운 2동 앞', 74),
#  ('215. 여의도고교 앞', 73),
#  ('565. 옥수역 3번출구', 73),
#  ('1911. 구로디지털단지역 앞', 73),
#  ('1925. 동양미래대학교 정문 옆', 73),
#  ('4076. 진영상운 앞 중랑천 변', 73),
#  ('247. 당산역 10번출구 앞', 72),
# ...

# %%
result = df.groupby("대여소명")['이용건수'].sum()
result = result.sort_values()
result #이거가 1번 정답
# Out:
# 대여소명
# 99998. 상암단말정비                  1
# 2391. 구룡터널 입구(개포1단지아파트)        4
# 9979. 테스트 대여소                  4
# 5082. 가양역 7번출구                 5
# 9998. 영남주차장 정비센터               6
#                            ...
# 207. 여의나루역 1번출구 앞          13574
# 2102. 봉림교 교통섬              13719
# 502. 뚝섬유원지역 1번출구 앞         14120
# 4217. 한강공원 망원나들목           15412
# 2715.마곡나루역 2번 출구           16494
# Name: 이용건수, Length: 2638, dtype: int64

# %%
df.groupby("대여소명")['이용건수'].sum()
# Out:
# 대여소명
# 1001. 광진교 남단 사거리(천호공원 방면)    2358
# 1002. 해공공원(천호동)              3230
# 1003. 해공도서관앞                 1389
# 1004. 삼성광나루아파트 버스정류장         2220
# 1006. 롯데캐슬 115동앞              429
#                              ...
# 사대문센터                           8
# 상담센터                          223
# 상암센터 정비실                       16
# 중랑센터                           67
# 천왕센터                           10
# Name: 이용건수, Length: 2638, dtype: int64

# %%
df
# Out:
#            대여일자  대여소번호            대여소명   대여구분코드  성별 연령대코드  이용건수     운동량   탄소량  \
# 0       2022-06      3            중랑센터  일일(비회원)  \N    기타     1   29.34  0.26
# 1       2022-06      3            중랑센터   일일(회원)   M   50대    19  458.11  4.44
# 2       2022-06      3            중랑센터       정기  \N   20대    12  330.13  3.39
# 3       2022-06      3            중랑센터       정기  \N   60대     4  113.53  1.02
# 4       2022-06      3            중랑센터       정기   M   20대     2   13.69  0.07
# ...         ...    ...             ...      ...  ..   ...   ...     ...   ...
# 133096  2022-06   9999            상담센터       정기   M    기타     4  525.03  3.84
# 133097  2022-06  88888      88888.영남배송       정기   M   60대     7  831.71  7.62
# 133098  2022-06  99998   99998. 상암단말정비       정기  \N   20대     1   20.85  0.26
# 133099  2022-06  99999  99999. 영남단말기정비       정기  \N    기타    15    0.00  0.00
# 133100  2022-06  99999  99999. 영남단말기정비       정기   M   30대     1   14.71  0.11
#
#          이동거리(M)  이용시간(분)
# ...

# %%
df_rocation = df[df['대여소명']=="4217. 한강공원 망원나들목"]
df_rocation
# Out:
#            대여일자  대여소번호              대여소명 대여구분코드  성별 연령대코드  이용건수        운동량  \
# 115854  2022-06   4217  4217. 한강공원 망원나들목     단체  \N   10대    37    4414.95
# 115855  2022-06   4217  4217. 한강공원 망원나들목     단체  \N   20대    63    9465.68
# 115856  2022-06   4217  4217. 한강공원 망원나들목     단체  \N   30대    41    4714.43
# 115857  2022-06   4217  4217. 한강공원 망원나들목     단체  \N   40대    27    4110.82
# 115858  2022-06   4217  4217. 한강공원 망원나들목     단체  \N   50대     2     164.85
# ...         ...    ...               ...    ...  ..   ...   ...        ...
# 115937  2022-06   4217  4217. 한강공원 망원나들목     정기   M   30대   590  103544.67
# 115938  2022-06   4217  4217. 한강공원 망원나들목     정기   M   40대   517   97886.98
# 115939  2022-06   4217  4217. 한강공원 망원나들목     정기   M   50대   170   29896.22
# 115940  2022-06   4217  4217. 한강공원 망원나들목     정기   M   60대   108   16644.19
# 115941  2022-06   4217  4217. 한강공원 망원나들목     정기   M    기타   224   35921.13
#
#            탄소량     이동거리(M)  이용시간(분)
# ...

# %%
df_rocation.groupby("연령대코드")['이용시간(분)'].sum()
# Out:
# 연령대코드
# 10대       33196
# 20대      243548
# 30대      128805
# 40대       95746
# 50대       44869
# 60대       16799
# 70대이상      1726
# 기타        89964
# Name: 이용시간(분), dtype: int64

# %%
df_rocation.groupby("연령대코드")['이용건수'].sum()
# Out:
# 연령대코드
# 10대       817
# 20대      6322
# 30대      3076
# 40대      1993
# 50대       927
# 60대       303
# 70대이상      30
# 기타       1944
# Name: 이용건수, dtype: int64

# %%
teenager = 33196 / 817
twenties = 243548 / 6322
thirties = 128805 / 3076
forties = 95746 / 1993
fifties = 44869 / 927
sixties = 16799 / 303
seventies_and_over = 1726 / 30
other_age = 89964 / 1944
age_list = [teenager, twenties, thirties, forties, fifties, sixties, seventies_and_over, other_age]
age_name_list = ["teenager", "twenties", "thirties", "forties", "fifties", "sixties", "seventies_and_over", "other_age"]
age_dict = {}
for i, j in zip(age_list,age_name_list):
    age_dict[j] = i

age_df = pd.DataFrame.from_dict([age_dict])
age_df
# Out:
#     teenager   twenties   thirties    forties    fifties    sixties  \
# 0  40.631579  38.523885  41.874187  48.041144  48.402373  55.442244
#
#    seventies_and_over  other_age
# 0           57.533333  46.277778

# %%
age_df = age_df.T #컬럼이랑 인덱스 서로 체인지
age_df
# Out:
#                             0
# teenager            40.631579
# twenties            38.523885
# thirties            41.874187
# forties             48.041144
# fifties             48.402373
# sixties             55.442244
# seventies_and_over  57.533333
# other_age           46.277778

# %%
import matplotlib.pyplot as plt
age_df = age_df.sort_values(by=0)
age_df.plot(kind='bar')
plt.show()
##이거가 2번의 정답임

# %%
df_rocation.groupby("연령대코드")['이용시간(분)'].sum()
# Out:
# 연령대코드
# 10대       33196
# 20대      243548
# 30대      128805
# 40대       95746
# 50대       44869
# 60대       16799
# 70대이상      1726
# 기타        89964
# Name: 이용시간(분), dtype: int64

# %%
teenager = 33196 / 88
twenties = 243548 / 88
thirties = 128805 / 88
forties = 95746 / 88
fifties = 44869 / 88
sixties = 16799 / 88
seventies_and_over = 1726 / 88
other_age = 89964 / 88
age_list = [teenager, twenties, thirties, forties, fifties, sixties, seventies_and_over, other_age]
age_name_list = ["teenager", "twenties", "thirties", "forties", "fifties", "sixties", "seventies_and_over", "other_age"]
age_dict = {}
for i, j in zip(age_list,age_name_list):
    age_dict[j] = i

age_df = pd.DataFrame.from_dict([age_dict])
age_df
# Out:
#      teenager     twenties     thirties      forties  fifties     sixties  \
# 0  377.227273  2767.590909  1463.693182  1088.022727  509.875  190.897727
#
#    seventies_and_over    other_age
# 0           19.613636  1022.318182

# %%
age_df = age_df.T #컬럼이랑 인덱스 서로 체인지
age_df
# Out:
#                               0
# teenager             377.227273
# twenties            2767.590909
# thirties            1463.693182
# forties             1088.022727
# fifties              509.875000
# sixties              190.897727
# seventies_and_over    19.613636
# other_age           1022.318182

# %%
age_df = age_df.sort_values(by=0)
age_df.plot(kind='bar')
plt.show()

# %%
df
# Out:
#            대여일자  대여소번호            대여소명   대여구분코드  성별 연령대코드  이용건수     운동량   탄소량  \
# 0       2022-06      3            중랑센터  일일(비회원)  \N    기타     1   29.34  0.26
# 1       2022-06      3            중랑센터   일일(회원)   M   50대    19  458.11  4.44
# 2       2022-06      3            중랑센터       정기  \N   20대    12  330.13  3.39
# 3       2022-06      3            중랑센터       정기  \N   60대     4  113.53  1.02
# 4       2022-06      3            중랑센터       정기   M   20대     2   13.69  0.07
# ...         ...    ...             ...      ...  ..   ...   ...     ...   ...
# 133096  2022-06   9999            상담센터       정기   M    기타     4  525.03  3.84
# 133097  2022-06  88888      88888.영남배송       정기   M   60대     7  831.71  7.62
# 133098  2022-06  99998   99998. 상암단말정비       정기  \N   20대     1   20.85  0.26
# 133099  2022-06  99999  99999. 영남단말기정비       정기  \N    기타    15    0.00  0.00
# 133100  2022-06  99999  99999. 영남단말기정비       정기   M   30대     1   14.71  0.11
#
#          이동거리(M)  이용시간(분)
# ...

# %%
df_m = df[df['성별'] == "M"]
df_m
# Out:
#            대여일자  대여소번호            대여소명  대여구분코드 성별 연령대코드  이용건수      운동량   탄소량  \
# 1       2022-06      3            중랑센터  일일(회원)  M   50대    19   458.11  4.44
# 4       2022-06      3            중랑센터      정기  M   20대     2    13.69  0.07
# 5       2022-06      3            중랑센터      정기  M   40대    12   622.21  4.54
# 6       2022-06      3            중랑센터      정기  M   50대    12   684.05  5.70
# 7       2022-06      3            중랑센터      정기  M   60대     4   146.80  1.18
# ...         ...    ...             ...     ... ..   ...   ...      ...   ...
# 133094  2022-06   9999            상담센터      정기  M   50대     8  1229.21  9.07
# 133095  2022-06   9999            상담센터      정기  M   60대     3    52.48  0.45
# 133096  2022-06   9999            상담센터      정기  M    기타     4   525.03  3.84
# 133097  2022-06  88888      88888.영남배송      정기  M   60대     7   831.71  7.62
# 133100  2022-06  99999  99999. 영남단말기정비      정기  M   30대     1    14.71  0.11
#
#          이동거리(M)  이용시간(분)
# ...

# %%
time_m = df_m['이용시간(분)'].sum()
count_m = df_m['이용건수'].sum()

print(time_m//count_m)
# Out:
# 21

# %%
df_w = df[df['성별'] == "F"]
df_w
# Out:
#            대여일자  대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수     운동량   탄소량  \
# 14      2022-06    102  102. 망원역 1번출구 앞     단체  F   10대     1  120.51  1.09
# 15      2022-06    102  102. 망원역 1번출구 앞     단체  F   20대     5  453.62  4.09
# 16      2022-06    102  102. 망원역 1번출구 앞     단체  F   30대     4  257.60  2.32
# 17      2022-06    102  102. 망원역 1번출구 앞     단체  F   40대     5  794.32  8.37
# 18      2022-06    102  102. 망원역 1번출구 앞     단체  F   50대     1  144.41  1.69
# ...         ...    ...              ...    ... ..   ...   ...     ...   ...
# 133085  2022-06   9999             상담센터     정기  F   30대     9  840.09  7.82
# 133086  2022-06   9999             상담센터     정기  F   40대    10  234.94  2.44
# 133087  2022-06   9999             상담센터     정기  F   50대     2  150.88  1.53
# 133088  2022-06   9999             상담센터     정기  F   60대     1   75.23  0.63
# 133089  2022-06   9999             상담센터     정기  F    기타     5  650.27  6.35
#
#          이동거리(M)  이용시간(분)
# 14       4681.84       82
# ...

# %%
time_w = df_w['이용시간(분)'].sum()
count_w = df_w['이용건수'].sum()

print(time_w//count_w)
# Out:
# 24

# %%
total_count = df['이용건수'].sum()
total_distance = df['이동거리(M)'].sum()

print(total_distance//total_count)
# Out:
# 2728.0
