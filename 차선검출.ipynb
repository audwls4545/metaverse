# %% [markdown]
# <a href="https://colab.research.google.com/github/audwls4545/metaverse/blob/main/%EC%B0%A8%EC%84%A0%EA%B2%80%EC%B6%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
road_img = cv2.imread('road1.jpg')
road_img = cv2.cvtColor(road_img, cv2.COLOR_BGR2RGB)
road_img = cv2.cvtColor(road_img, cv2.COLOR_RGB2GRAY)
cv2_imshow(road_img)
# Out:
# <PIL.Image.Image image mode=L size=1400x1098 at 0x7B821C1534C0>
